# %% [markdown]
# # 파이썬 기초
#
# ## 자료 구조
#
# 중요한 *내용* 적습니다.
#
# 표 1
#
# | 이름 | 소속 |
# |-|-|
# |홍길동|활빈당|
# |심청|임당수|
#
# 항목 목록 `list`
# - 항목1
# - 항목2
#
#
# 순서 있는 목록
# 1. 하나
# 2. 둘
#
# --------
#
# ```python
# a = 10
# b = 3.14
# ```

# %% [markdown]
# ## 새로운 공간

# %%
a = 10
b = 3.14

print("Integer a:", a)
print("Float b:", b)
# Out:
# Integer a: 10
# Float b: 3.14
